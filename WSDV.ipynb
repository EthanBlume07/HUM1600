# %%
# Ethan Blume
# 3/23/24
# Web scraping is what it sounds like, taking data from webpages. Legally and ethically, some places do not approve of web scraping their data, such as Microsoft.
# A trend line indicates a general movement in the data, be it up, down or stagnant. It shows simply where the data started and where it could be heading, always showing the average of points.

# %%
# Problem 1
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/wiki/Gothic_fiction'
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    for link in soup.find_all('a'):
        href = link.get('href')
        if href and href.startswith('http'):
            print(href)
else:
    print("Failed to retrieve the webpage")
# Out:
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# https://ar.wikipedia.org/wiki/%D8%AE%D9%8A%D8%A7%D9%84_%D9%82%D9%88%D8%B7%D9%8A
# https://bn.wikipedia.org/wiki/%E0%A6%97%E0%A6%A5%E0%A6%BF%E0%A6%95_%E0%A6%95%E0%A6%B2%E0%A7%8D%E0%A6%AA%E0%A6%95%E0%A6%BE%E0%A6%B9%E0%A6%BF%E0%A6%A8%E0%A7%80
# https://cs.wikipedia.org/wiki/Goti%C4%8Dno
# https://fa.wikipedia.org/wiki/%D8%A7%D8%AF%D8%A8%DB%8C%D8%A7%D8%AA_%DA%AF%D9%88%D8%AA%DB%8C%DA%A9
# https://ko.wikipedia.org/wiki/%EA%B3%A0%EB%94%95%EB%AC%BC
# https://id.wikipedia.org/wiki/Fiksi_Gotik
# https://la.wikipedia.org/wiki/Fictio_gothica
# https://simple.wikipedia.org/wiki/Gothic_fiction
# https://sr.wikipedia.org/wiki/Goti%C4%8Dki_roman
# https://sv.wikipedia.org/wiki/Gotisk_fiktion
# ...

# %%
# Problem 2
import matplotlib.pyplot as plt
x = [2,2,3,3,7,15,15,21,21,21,22,22,24,30,33,38,39,42,47,49,51,51,52,53,55,58,59,60,60,61]
y = [-19.26,12.19,9.29,-9.51,14.80,11.23,3.63,-1.08,16.16,3.45,-2.77,7.46,7.38,15.66,14.73,31.00,26.48,19.28,14.42,36.38,33.35,52.06,28.63,42.91,32.10,29.85,14.40,37.21,21.56,25.36]
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Line Graph Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
plt.show()

x = [2,2,3,3,7,15,15,21,21,21,22,22,24,30,33,38,39,42,47,49,51,51,52,53,55,58,59,60,60,61]
y = [-19.26,12.19,9.29,-9.51,14.80,11.23,3.63,-1.08,16.16,3.45,-2.77,7.46,7.38,15.66,14.73,31.00,26.48,19.28,14.42,36.38,33.35,52.06,28.63,42.91,32.10,29.85,14.40,37.21,21.56,25.36]
plt.scatter(x, y, c='blue', marker='o', edgecolor='blue', linewidth=1, alpha=0.75)
plt.title('Scatter Plot')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

import numpy as np
x = np.array([2,2,3,3,7,15,15,21,21,21,22,22,24,30,33,38,39,42,47,49,51,51,52,53,55,58,59,60,60,61])
y = np.array([-19.26,12.19,9.29,-9.51,14.80,11.23,3.63,-1.08,16.16,3.45,-2.77,7.46,7.38,15.66,14.73,31.00,26.48,19.28,14.42,36.38,33.35,52.06,28.63,42.91,32.10,29.85,14.40,37.21,21.56,25.36])
plt.scatter(x, y, c='blue', marker='o', edgecolor='black', linewidth=1, alpha=0.75, label='Data Points')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red', linewidth=1, label='Trend Line')
plt.title('Scatter Plot with Trend Line')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
# Problem 3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = [
["Reese",112,47],
["Barnes",103,87],
["Jones",127,70],
["Javez",99,51],
["Smith",130,100],
["Heath",107,101],
["Jacks",89,38],
["Weeks",120,97],
["Mitch",122,110],
["Rankle",90,55]
]
df = pd.DataFrame(data, columns=['Team', 'High Score', 'Low Score'])
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Team', y='High Score', data=df, color='red', label='High Score')
sns.scatterplot(x='Team', y='Low Score', data=df, color='blue', label='Low Score')
plt.title('Team High and Low Scores')
plt.xlabel('Team')
plt.ylabel('Score')
plt.xticks(rotation=90)
plt.legend()
plt.show()
